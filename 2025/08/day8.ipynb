# %%
import numpy as np
coordinates = np.loadtxt('day8.txt', dtype=int, delimiter=",")

# %%
distances = np.zeros((coordinates.shape[0], coordinates.shape[0]))

for i in range(coordinates.shape[0]):
    for j in range(coordinates.shape[0]):
        coord1 = (coordinates[j][0] - coordinates[i][0])**2
        coord2 = (coordinates[j][1] - coordinates[i][1])**2
        coord3 = (coordinates[j][2] - coordinates[i][2])**2
        distances[i,j] = np.sqrt(coord1 + coord2 + coord3)

np.fill_diagonal(distances, np.inf)

# %%
pd.DataFrame(distances)
# Out:
#              0            1            2            3           4   \
# 0           inf   787.814064   908.784353   561.718791  723.787952
# 1    787.814064          inf  1019.987255  1041.746130  471.433983
# 2    908.784353  1019.987255          inf   507.106498  612.241782
# 3    561.718791  1041.746130   507.106498          inf  697.114768
# 4    723.787952   471.433983   612.241782   697.114768         inf
# 5    736.432617   424.242855   670.871076   814.322418  373.411301
# 6   1047.434962   783.700836   589.095069   837.028076  371.705529
# 7    321.560259  1024.444240   790.590918   384.630992  844.318660
# 8    693.205597   795.882529   347.598907   524.905706  521.717356
# 9    391.465196   628.689112   867.801821   604.702406  491.739769
# 10   693.095953  1046.166813   834.137279   503.620889  717.802898
# 11  1044.502274   847.541149   833.343867  1076.883002  844.770975
# 12   709.048658   655.613453   812.579227   700.318499  372.022849
# 13   970.926877  1124.700849   322.369353   492.628663  661.777908
# 14   413.516626   600.302424   818.142408   711.401434  629.317885
# 15  1103.559695   913.531061   540.282334   941.957536  708.093920
# 16   927.685830  1001.084412   671.054394   863.711179  878.818525
# 17  1290.451471   979.161887   605.773885  1032.787006  639.754640
# 18  1191.777244  1103.799801   352.936255   811.571932  681.072683
# 19   316.902193   734.868696   597.412755   367.982337  527.023719
#
#              5            6            7           8            9   \
# 0    736.432617  1047.434962   321.560259  693.205597   391.465196
# 1    424.242855   783.700836  1024.444240  795.882529   628.689112
# 2    670.871076   589.095069   790.590918  347.598907   867.801821
# 3    814.322418   837.028076   384.630992  524.905706   604.702406
# 4    373.411301   371.705529   844.318660  521.717356   491.739769
# 5           inf   648.213699   845.443079  411.967232   686.075798
# 6    648.213699          inf  1100.654805  690.905203   788.165592
# 7    845.443079  1100.654805          inf  630.851013   609.972131
# 8    411.967232   690.905203   630.851013         inf   738.358314
# 9    686.075798   788.165592   609.972131  738.358314          inf
# 10  1002.868386   817.952321   712.311028  888.068691   476.815478
# 11   495.953627  1020.792339  1057.207643  566.279966  1130.521119
# 12   714.272357   535.146709   860.237758  789.496042   338.338588
# 13   867.383422   550.544276   863.623761  610.960719   842.077194
# 14   433.849052   968.357372   543.217268  493.811705   597.227762
# 15   511.590657   740.597056  1069.869618  444.375967  1095.513122
# 16   603.633995  1048.481283   841.562832  417.527245  1082.328046
# 17   735.114957   379.242666  1295.247467  740.142554  1106.376970
# 18   796.678103   459.344098  1121.531988  621.508648  1056.638065
# 19   533.034708   809.826525   328.118881  387.201498   433.555071
#
#              10           11           12           13           14  \
# 0    693.095953  1044.502274   709.048658   970.926877   413.516626
# 1   1046.166813   847.541149   655.613453  1124.700849   600.302424
# 2    834.137279   833.343867   812.579227   322.369353   818.142408
# 3    503.620889  1076.883002   700.318499   492.628663   711.401434
# 4    717.802898   844.770975   372.022849   661.777908   629.317885
# 5   1002.868386   495.953627   714.272357   867.383422   433.849052
# 6    817.952321  1020.792339   535.146709   550.544276   968.357372
# 7    712.311028  1057.207643   860.237758   863.623761   543.217268
# 8    888.068691   566.279966   789.496042   610.960719   493.811705
# 9    476.815478  1130.521119   338.338588   842.077194   597.227762
# 10          inf  1410.875969   458.360120   646.579461   960.640411
# 11  1410.875969          inf  1194.030569  1131.320467   652.592522
# 12   458.360120  1194.030569          inf   716.067734   816.393288
# 13   646.579461  1131.320467   716.067734          inf  1000.145489
# 14   960.640411   652.592522   816.393288  1000.145489          inf
# 15  1256.502288   407.535275  1059.614081   830.490819   802.381455
# 16  1284.057242   344.389315  1181.397901   981.697509   609.784388
# 17  1145.384215   927.153709   900.832393   683.281787  1113.804741
# 18   996.709085   966.708850   889.978090   411.944171  1075.349711
# 19   650.046921   832.878142   626.601149   705.628798   350.786260
#
#              15           16           17           18           19
# 0   1103.559695   927.685830  1290.451471  1191.777244   316.902193
# 1    913.531061  1001.084412   979.161887  1103.799801   734.868696
# 2    540.282334   671.054394   605.773885   352.936255   597.412755
# 3    941.957536   863.711179  1032.787006   811.571932   367.982337
# 4    708.093920   878.818525   639.754640   681.072683   527.023719
# 5    511.590657   603.633995   735.114957   796.678103   533.034708
# 6    740.597056  1048.481283   379.242666   459.344098   809.826525
# 7   1069.869618   841.562832  1295.247467  1121.531988   328.118881
# 8    444.375967   417.527245   740.142554   621.508648   387.201498
# 9   1095.513122  1082.328046  1106.376970  1056.638065   433.555071
# 10  1256.502288  1284.057242  1145.384215   996.709085   650.046921
# 11   407.535275   344.389315   927.153709   966.708850   832.878142
# 12  1059.614081  1181.397901   900.832393   889.978090   626.601149
# 13   830.490819   981.697509   683.281787   411.944171   705.628798
# 14   802.381455   609.784388  1113.804741  1075.349711   350.786260
# 15          inf   455.224121   566.911810   582.461158   814.770520
# 16   455.224121          inf   983.814007   902.034367   692.723610
# 17   566.911810   983.814007          inf   333.655511  1007.137528
# 18   582.461158   902.034367   333.655511          inf   888.318637
# 19   814.770520   692.723610  1007.137528   888.318637          inf

# %%
flat_distances = distances.ravel()

def find_k_smallest_dist(flat_distances, k):
    kth_flat_index_position = np.argpartition(flat_distances, k - 1)[k - 1]
    kth_min_value = np.partition(flat_distances, k - 1)[k - 1]
    kth_flat_index = np.where(flat_distances == kth_min_value)[0][0]
    row, col = np.unravel_index(kth_flat_index, distances.shape)

    return row, col


def consolidate_connections(conn_list):
    """Merge any overlapping lists"""
    changed = True
    while changed:
        changed = False
        for i in range(len(conn_list)):
            for j in range(i + 1, len(conn_list)):
                set_i = set(conn_list[i])
                set_j = set(conn_list[j])
                if not set_i.isdisjoint(set_j):
                    conn_list[i] = list(set_i.union(set_j))
                    conn_list.pop(j)
                    changed = True
                    break
            if changed:
                break
    return conn_list

def find_k_smallest_unique_dist(distances, k):
    rows_ut, cols_ut = np.triu_indices_from(distances, k=1)
    unique_distances_subset = distances[rows_ut, cols_ut]
    sorted_indices_of_subset = np.argsort(unique_distances_subset)
    
    if k > len(sorted_indices_of_subset) or k < 1:
        raise IndexError(f"k={k} is out of range for the number of unique distances ({len(sorted_indices_of_subset)})")

    kth_position = k - 1
    
    row = rows_ut[sorted_indices_of_subset[kth_position]]
    col = cols_ut[sorted_indices_of_subset[kth_position]]

    return row, col

connections = []
row, col = find_k_smallest_unique_dist(distances, 1)
connections.append([row, col])
k = 2
num_conn = 1
max_num_conn = 1000
while num_conn <= max_num_conn:
    row, col = find_k_smallest_unique_dist(distances, k)
    #print(num_conn, row, col)
    elements_to_add = {row, col}
    merged = False

    for i, inner_list in enumerate(connections):
        current_set = set(inner_list)
        has_overlap = not elements_to_add.isdisjoint(current_set)
        contains_all_new = elements_to_add.issubset(current_set)

        if contains_all_new:
            merged = True
            break

        if has_overlap and not contains_all_new:
            connections[i] = list(current_set.union(elements_to_add))
            merged = True
            break
    if not merged:
        connections.append(list(elements_to_add))    

    connections = consolidate_connections(connections)

    k += 1
    num_conn += 1

    #print(connections)      
connections
# Out:
# [[np.int64(130),
#   np.int64(132),
#   np.int64(772),
#   np.int64(390),
#   np.int64(647),
#   np.int64(396),
#   np.int64(142),
#   np.int64(147),
#   np.int64(277),
#   np.int64(791),
#   np.int64(152),
#   np.int64(411),
#   np.int64(668),
#   np.int64(797),
#   np.int64(671),
#   np.int64(416),
#   np.int64(290),
#   np.int64(932),
#   np.int64(166),
#   np.int64(169),
#   np.int64(811),
#   np.int64(46),
#   np.int64(943),
#   np.int64(176),
#   np.int64(689),
#   np.int64(308),
#   np.int64(568),
#   np.int64(56),
#   np.int64(443),
#   np.int64(571),
#   np.int64(962),
#   np.int64(835),
#   np.int64(578),
#   np.int64(584),
#   np.int64(207),
#   np.int64(978),
#   np.int64(210),
#   np.int64(732),
#   np.int64(348),
#   np.int64(477),
#   np.int64(350),
#   np.int64(607),
#   np.int64(865),
#   np.int64(98),
#   np.int64(100),
#   np.int64(232),
#   np.int64(107),
#   np.int64(877),
#   np.int64(622),
#   np.int64(751),
#   np.int64(124),
#   np.int64(245),
#   np.int64(374),
#   np.int64(890),
#   np.int64(635),
#   np.int64(764),
#   np.int64(637),
#   np.int64(255)],
#  [np.int64(896),
#   np.int64(720),
#   np.int64(792),
#   np.int64(888),
#   np.int64(373),
#   np.int64(504)],
#  [np.int64(641),
#   np.int64(203),
#   np.int64(459),
#   np.int64(946),
#   np.int64(787),
#   np.int64(980),
#   np.int64(826)],
#  [np.int64(259),
#   np.int64(387),
#   np.int64(389),
#   np.int64(419),
#   np.int64(7),
#   np.int64(739),
#   np.int64(430),
#   np.int64(240),
#   np.int64(944),
#   np.int64(405),
#   np.int64(182),
#   np.int64(281),
#   np.int64(314)],
#  [np.int64(833),
#   np.int64(133),
#   np.int64(328),
#   np.int64(140),
#   np.int64(782),
#   np.int64(847),
#   np.int64(656),
#   np.int64(151),
#   np.int64(796),
#   np.int64(544),
#   np.int64(609),
#   np.int64(163),
#   np.int64(357),
#   np.int64(678),
#   np.int64(38),
#   np.int64(881),
#   np.int64(691),
#   np.int64(52),
#   np.int64(187)],
#  [np.int64(128),
#   np.int64(65),
#   np.int64(354),
#   np.int64(709),
#   np.int64(137),
#   np.int64(266),
#   np.int64(692),
#   np.int64(153),
#   np.int64(543)],
#  [np.int64(499), np.int64(454)],
#  [np.int64(195),
#   np.int64(457),
#   np.int64(11),
#   np.int64(651),
#   np.int64(461),
#   np.int64(270),
#   np.int64(271),
#   np.int64(80),
#   np.int64(403),
#   np.int64(724),
#   np.int64(148),
#   np.int64(664),
#   np.int64(603),
#   np.int64(32),
#   np.int64(809),
#   np.int64(494),
#   np.int64(879),
#   np.int64(496),
#   np.int64(113),
#   np.int64(626),
#   np.int64(886),
#   np.int64(118)],
#  [np.int64(902),
#   np.int64(263),
#   np.int64(170),
#   np.int64(267),
#   np.int64(975),
#   np.int64(820),
#   np.int64(342),
#   np.int64(471),
#   np.int64(858),
#   np.int64(863)],
#  [np.int64(146), np.int64(371), np.int64(358), np.int64(120), np.int64(205)],
#  [np.int64(472), np.int64(658), np.int64(917)],
#  [np.int64(710), np.int64(86)],
#  [np.int64(592), np.int64(375)],
#  [np.int64(832),
#   np.int64(385),
#   np.int64(966),
#   np.int64(391),
#   np.int64(840),
#   np.int64(841),
#   np.int64(714),
#   np.int64(849),
#   np.int64(21),
#   np.int64(597),
#   np.int64(536),
#   np.int64(794),
#   np.int64(474),
#   np.int64(927),
#   np.int64(226),
#   np.int64(675),
#   np.int64(227),
#   np.int64(421),
#   np.int64(612),
#   np.int64(168),
#   np.int64(425),
#   np.int64(939),
#   np.int64(559),
#   np.int64(117),
#   np.int64(952),
#   np.int64(441),
#   np.int64(126),
#   np.int64(892),
#   np.int64(574),
#   np.int64(575)],
#  [np.int64(707),
#   np.int64(68),
#   np.int64(516),
#   np.int64(326),
#   np.int64(455),
#   np.int64(330),
#   np.int64(590),
#   np.int64(591),
#   np.int64(145),
#   np.int64(17),
#   np.int64(916),
#   np.int64(216),
#   np.int64(409),
#   np.int64(155),
#   np.int64(349),
#   np.int64(414),
#   np.int64(990),
#   np.int64(223),
#   np.int64(417),
#   np.int64(479),
#   np.int64(547),
#   np.int64(99),
#   np.int64(229),
#   np.int64(869),
#   np.int64(489),
#   np.int64(814),
#   np.int64(47),
#   np.int64(695),
#   np.int64(312)],
#  [np.int64(384),
#   np.int64(992),
#   np.int64(515),
#   np.int64(452),
#   np.int64(149),
#   np.int64(648),
#   np.int64(522)],
#  [np.int64(480), np.int64(313), np.int64(539)],
#  [np.int64(513),
#   np.int64(134),
#   np.int64(8),
#   np.int64(521),
#   np.int64(906),
#   np.int64(265),
#   np.int64(655),
#   np.int64(912),
#   np.int64(785),
#   np.int64(788),
#   np.int64(157),
#   np.int64(926),
#   np.int64(287),
#   np.int64(800),
#   np.int64(929),
#   np.int64(167),
#   np.int64(808),
#   np.int64(41),
#   np.int64(42),
#   np.int64(304),
#   np.int64(949),
#   np.int64(309),
#   np.int64(439),
#   np.int64(184),
#   np.int64(569),
#   np.int64(829),
#   np.int64(189),
#   np.int64(577),
#   np.int64(72),
#   np.int64(329),
#   np.int64(969),
#   np.int64(715),
#   np.int64(716),
#   np.int64(206),
#   np.int64(469),
#   np.int64(343),
#   np.int64(218),
#   np.int64(91),
#   np.int64(988),
#   np.int64(736),
#   np.int64(993),
#   np.int64(616),
#   np.int64(619),
#   np.int64(108),
#   np.int64(238),
#   np.int64(629),
#   np.int64(633),
#   np.int64(380)],
#  [np.int64(192),
#   np.int64(199),
#   np.int64(458),
#   np.int64(74),
#   np.int64(524),
#   np.int64(845),
#   np.int64(272),
#   np.int64(534),
#   np.int64(278),
#   np.int64(859),
#   np.int64(156),
#   np.int64(925),
#   np.int64(604),
#   np.int64(161),
#   np.int64(101),
#   np.int64(614),
#   np.int64(236),
#   np.int64(882),
#   np.int64(825),
#   np.int64(185)],
#  [np.int64(960),
#   np.int64(289),
#   np.int64(740),
#   np.int64(135),
#   np.int64(13),
#   np.int64(749),
#   np.int64(114),
#   np.int64(757),
#   np.int64(822),
#   np.int64(920),
#   np.int64(58),
#   np.int64(413),
#   np.int64(895)],
#  [np.int64(352),
#   np.int64(613),
#   np.int64(871),
#   np.int64(200),
#   np.int64(555),
#   np.int64(398),
#   np.int64(179),
#   np.int64(341),
#   np.int64(981)],
#  [np.int64(324),
#   np.int64(549),
#   np.int64(918),
#   np.int64(777),
#   np.int64(190),
#   np.int64(30),
#   np.int64(159)],
#  [np.int64(1), np.int64(733)],
#  [np.int64(834),
#   np.int64(261),
#   np.int64(9),
#   np.int64(843),
#   np.int64(909),
#   np.int64(78),
#   np.int64(401),
#   np.int64(726),
#   np.int64(599),
#   np.int64(408),
#   np.int64(982),
#   np.int64(347),
#   np.int64(92),
#   np.int64(545),
#   np.int64(102),
#   np.int64(551),
#   np.int64(103),
#   np.int64(488),
#   np.int64(938),
#   np.int64(813),
#   np.int64(188),
#   np.int64(894)],
#  [np.int64(33),
#   np.int64(721),
#   np.int64(3),
#   np.int64(964),
#   np.int64(718),
#   np.int64(319)],
#  [np.int64(449), np.int64(770), np.int64(666), np.int64(942)],
#  [np.int64(353),
#   np.int64(535),
#   np.int64(615),
#   np.int64(680),
#   np.int64(807),
#   np.int64(269),
#   np.int64(14),
#   np.int64(467),
#   np.int64(22),
#   np.int64(759),
#   np.int64(566),
#   np.int64(377),
#   np.int64(634),
#   np.int64(701),
#   np.int64(447)],
#  [np.int64(617), np.int64(20), np.int64(957)],
#  [np.int64(291),
#   np.int64(580),
#   np.int64(139),
#   np.int64(497),
#   np.int64(115),
#   np.int64(851),
#   np.int64(212),
#   np.int64(63)],
#  [np.int64(728), np.int64(901), np.int64(598)],
#  [np.int64(66), np.int64(819)],
#  [np.int64(705), np.int64(844), np.int64(215)],
#  [np.int64(769),
#   np.int64(451),
#   np.int64(518),
#   np.int64(460),
#   np.int64(784),
#   np.int64(663),
#   np.int64(669),
#   np.int64(478),
#   np.int64(995),
#   np.int64(741),
#   np.int64(552),
#   np.int64(43),
#   np.int64(111),
#   np.int64(690),
#   np.int64(51),
#   np.int64(948),
#   np.int64(562),
#   np.int64(122),
#   np.int64(445)],
#  [np.int64(986), np.int64(699), np.int64(573)],
#  [np.int64(900), np.int64(71), np.int64(589), np.int64(335)],
#  [np.int64(402), np.int64(790)],
#  [np.int64(448),
#   np.int64(392),
#   np.int64(462),
#   np.int64(853),
#   np.int64(279),
#   np.int64(87),
#   np.int64(921),
#   np.int64(346),
#   np.int64(481),
#   np.int64(677),
#   np.int64(933),
#   np.int64(296),
#   np.int64(299),
#   np.int64(556),
#   np.int64(173),
#   np.int64(491),
#   np.int64(110),
#   np.int64(310),
#   np.int64(311),
#   np.int64(760),
#   np.int64(249),
#   np.int64(59),
#   np.int64(60)],
#  [np.int64(754), np.int64(548), np.int64(453), np.int64(219)],
#  [np.int64(640),
#   np.int64(643),
#   np.int64(517),
#   np.int64(105),
#   np.int64(399),
#   np.int64(560),
#   np.int64(914),
#   np.int64(661),
#   np.int64(25),
#   np.int64(572),
#   np.int64(412)],
#  [np.int64(955),
#   np.int64(681),
#   np.int64(368),
#   np.int64(945),
#   np.int64(242),
#   np.int64(24),
#   np.int64(507),
#   np.int64(125),
#   np.int64(510),
#   np.int64(31)],
#  [np.int64(928),
#   np.int64(708),
#   np.int64(903),
#   np.int64(848),
#   np.int64(112),
#   np.int64(758),
#   np.int64(632),
#   np.int64(697),
#   np.int64(570)],
#  [np.int64(250), np.int64(884)],
#  [np.int64(336),
#   np.int64(771),
#   np.int64(83),
#   np.int64(854),
#   np.int64(10),
#   np.int64(410)],
#  [np.int64(850), np.int64(950), np.int64(138), np.int64(558)],
#  [np.int64(12), np.int64(44)],
#  [np.int64(696), np.int64(985), np.int64(5)],
#  [np.int64(0),
#   np.int64(433),
#   np.int64(369),
#   np.int64(64),
#   np.int64(725),
#   np.int64(262)],
#  [np.int64(650),
#   np.int64(652),
#   np.int64(908),
#   np.int64(795),
#   np.int64(731),
#   np.int64(225),
#   np.int64(803),
#   np.int64(295),
#   np.int64(297),
#   np.int64(746),
#   np.int64(875),
#   np.int64(745),
#   np.int64(239),
#   np.int64(434),
#   np.int64(755),
#   np.int64(180),
#   np.int64(53),
#   np.int64(698),
#   np.int64(827)],
#  [np.int64(582),
#   np.int64(646),
#   np.int64(583),
#   np.int64(585),
#   np.int64(587),
#   np.int64(972),
#   np.int64(77),
#   np.int64(527),
#   np.int64(528),
#   np.int64(406),
#   np.int64(801),
#   np.int64(162),
#   np.int64(743),
#   np.int64(302),
#   np.int64(495),
#   np.int64(624),
#   np.int64(440),
#   np.int64(954)],
#  [np.int64(298), np.int64(252), np.int64(838)],
#  [np.int64(67), np.int64(899), np.int64(340), np.int64(557)],
#  [np.int64(97),
#   np.int64(260),
#   np.int64(965),
#   np.int64(70),
#   np.int64(332),
#   np.int64(878),
#   np.int64(303),
#   np.int64(625),
#   np.int64(351)],
#  [np.int64(593), np.int64(235)],
#  [np.int64(498), np.int64(767), np.int64(874), np.int64(687)],
#  [np.int64(485),
#   np.int64(475),
#   np.int64(423),
#   np.int64(924),
#   np.int64(683),
#   np.int64(812)],
#  [np.int64(953), np.int64(379)],
#  [np.int64(976), np.int64(248), np.int64(761), np.int64(366)],
#  [np.int64(35),
#   np.int64(679),
#   np.int64(463),
#   np.int64(880),
#   np.int64(370),
#   np.int64(923),
#   np.int64(542),
#   np.int64(735)],
#  [np.int64(337), np.int64(213)],
#  [np.int64(82),
#   np.int64(275),
#   np.int64(915),
#   np.int64(712),
#   np.int64(202),
#   np.int64(815)],
#  [np.int64(464), np.int64(996), np.int64(821), np.int64(356), np.int64(40)],
#  [np.int64(450),
#   np.int64(2),
#   np.int64(484),
#   np.int64(293),
#   np.int64(136),
#   np.int64(106),
#   np.int64(971),
#   np.int64(84),
#   np.int64(693),
#   np.int64(694)],
#  [np.int64(121), np.int64(554), np.int64(503)],
#  [np.int64(327),
#   np.int64(776),
#   np.int64(204),
#   np.int64(781),
#   np.int64(492),
#   np.int64(333),
#   np.int64(150),
#   np.int64(667)],
#  [np.int64(228), np.int64(564)],
#  [np.int64(288), np.int64(482), np.int64(233), np.int64(682)],
#  [np.int64(576),
#   np.int64(581),
#   np.int64(487),
#   np.int64(428),
#   np.int64(397),
#   np.int64(15),
#   np.int64(602),
#   np.int64(222)],
#  [np.int64(104), np.int64(512)],
#  [np.int64(672), np.int64(19), np.int64(595)],
#  [np.int64(873), np.int64(514), np.int64(220)],
#  [np.int64(864),
#   np.int64(737),
#   np.int64(898),
#   np.int64(197),
#   np.int64(422),
#   np.int64(937),
#   np.int64(526),
#   np.int64(529),
#   np.int64(786),
#   np.int64(753),
#   np.int64(468),
#   np.int64(376),
#   np.int64(730),
#   np.int64(700),
#   np.int64(381)],
#  [np.int64(338), np.int64(659), np.int64(490), np.int64(431)],
#  [np.int64(26), np.int64(852)],
#  [np.int64(974),
#   np.int64(274),
#   np.int64(563),
#   np.int64(533),
#   np.int64(316),
#   np.int64(983),
#   np.int64(444),
#   np.int64(27),
#   np.int64(508),
#   np.int64(415)],
#  [np.int64(872), np.int64(500)],
#  [np.int64(561), np.int64(947), np.int64(364), np.int64(748)],
#  [np.int64(81),
#   np.int64(34),
#   np.int64(611),
#   np.int64(247),
#   np.int64(201),
#   np.int64(382),
#   np.int64(511)],
#  [np.int64(893), np.int64(567)],
#  [np.int64(704),
#   np.int64(386),
#   np.int64(810),
#   np.int64(523),
#   np.int64(175),
#   np.int64(816),
#   np.int64(857),
#   np.int64(830)],
#  [np.int64(674), np.int64(951)],
#  [np.int64(331), np.int64(989)],
#  [np.int64(320),
#   np.int64(546),
#   np.int64(644),
#   np.int64(362),
#   np.int64(334),
#   np.int64(686),
#   np.int64(885),
#   np.int64(119)],
#  [np.int64(977), np.int64(54)],
#  [np.int64(789), np.int64(438)],
#  [np.int64(129), np.int64(868)],
#  [np.int64(738), np.int64(317)],
#  [np.int64(466),
#   np.int64(645),
#   np.int64(344),
#   np.int64(57),
#   np.int64(670),
#   np.int64(79)],
#  [np.int64(323), np.int64(62), np.int64(959)],
#  [np.int64(987), np.int64(842), np.int64(282), np.int64(973), np.int64(862)],
#  [np.int64(897),
#   np.int64(355),
#   np.int64(420),
#   np.int64(230),
#   np.int64(818),
#   np.int64(855),
#   np.int64(29),
#   np.int64(606)],
#  [np.int64(88), np.int64(231)],
#  [np.int64(836), np.int64(958), np.int64(476), np.int64(798), np.int64(286)],
#  [np.int64(861), np.int64(823)],
#  [np.int64(936), np.int64(727)],
#  [np.int64(217), np.int64(717), np.int64(799)],
#  [np.int64(684), np.int64(532), np.int64(165)],
#  [np.int64(50), np.int64(594), np.int64(404), np.int64(620)],
#  [np.int64(904), np.int64(395), np.int64(831)],
#  [np.int64(254), np.int64(127)],
#  [np.int64(763), np.int64(774)],
#  [np.int64(383), np.int64(285), np.int64(887)],
#  [np.int64(501), np.int64(181)],
#  [np.int64(160), np.int64(325), np.int64(363), np.int64(540), np.int64(141)],
#  [np.int64(456), np.int64(243)],
#  [np.int64(306), np.int64(662), np.int64(315), np.int64(95)],
#  [np.int64(930), np.int64(506)],
#  [np.int64(802), np.int64(4), np.int64(292), np.int64(520)],
#  [np.int64(493),
#   np.int64(605),
#   np.int64(244),
#   np.int64(779),
#   np.int64(365),
#   np.int64(734)],
#  [np.int64(722), np.int64(628), np.int64(742), np.int64(685)],
#  [np.int64(883), np.int64(253), np.int64(630)],
#  [np.int64(321), np.int64(257)],
#  [np.int64(418), np.int64(636), np.int64(998)],
#  [np.int64(208), np.int64(470), np.int64(234), np.int64(28)],
#  [np.int64(209), np.int64(427), np.int64(93)],
#  [np.int64(432), np.int64(194)],
#  [np.int64(806), np.int64(191)],
#  [np.int64(424), np.int64(828)],
#  [np.int64(970), np.int64(631)],
#  [np.int64(601), np.int64(756), np.int64(486)],
#  [np.int64(891), np.int64(174)],
#  [np.int64(723), np.int64(550)],
#  [np.int64(538), np.int64(36)],
#  [np.int64(473), np.int64(919)],
#  [np.int64(778), np.int64(45)],
#  [np.int64(378), np.int64(525)],
#  [np.int64(361), np.int64(69)],
#  [np.int64(436), np.int64(565)],
#  [np.int64(968), np.int64(913), np.int64(429)],
#  [np.int64(639), np.int64(359)],
#  [np.int64(339), np.int64(967), np.int64(505), np.int64(283)],
#  [np.int64(729), np.int64(258), np.int64(922)],
#  [np.int64(360), np.int64(747)],
#  [np.int64(984), np.int64(654)],
#  [np.int64(600), np.int64(608), np.int64(446)],
#  [np.int64(752), np.int64(394)],
#  [np.int64(963), np.int64(588), np.int64(623)],
#  [np.int64(713), np.int64(276)],
#  [np.int64(300), np.int64(318)],
#  [np.int64(442), np.int64(483), np.int64(502)],
#  [np.int64(437), np.int64(55), np.int64(621), np.int64(839)],
#  [np.int64(211), np.int64(660)],
#  [np.int64(144), np.int64(856), np.int64(407)],
#  [np.int64(793), np.int64(143)],
#  [np.int64(627), np.int64(61)]]

# %%
connections
# Out:
# [[np.int64(0), np.int64(19), np.int64(3), np.int64(7), np.int64(14)],
#  [np.int64(2), np.int64(18), np.int64(8), np.int64(13)],
#  [np.int64(17), np.int64(18)],
#  [np.int64(9), np.int64(12)],
#  [np.int64(16), np.int64(11)]]

# %%
lengths_list = sorted([len(sublist) for sublist in connections], reverse=True)
print(lengths_list[0]*lengths_list[1]*lengths_list[2])
# Out:
# 83520

# %%
def consolidate_connections(conn_list):
    """Merge any overlapping lists"""
    changed = True
    while changed:
        changed = False
        for i in range(len(conn_list)):
            for j in range(i + 1, len(conn_list)):
                set_i = set(conn_list[i])
                set_j = set(conn_list[j])
                if not set_i.isdisjoint(set_j):
                    conn_list[i] = list(set_i.union(set_j))
                    conn_list.pop(j)
                    changed = True
                    break
            if changed:
                break
    return conn_list

def find_k_smallest_unique_dist(distances, k):
    rows_ut, cols_ut = np.triu_indices_from(distances, k=1)
    unique_distances_subset = distances[rows_ut, cols_ut]
    sorted_indices_of_subset = np.argsort(unique_distances_subset)
    
    if k > len(sorted_indices_of_subset) or k < 1:
        raise IndexError(f"k={k} is out of range for the number of unique distances ({len(sorted_indices_of_subset)})")

    kth_position = k - 1
    
    row = rows_ut[sorted_indices_of_subset[kth_position]]
    col = cols_ut[sorted_indices_of_subset[kth_position]]

    return row, col

connections = []
row, col = find_k_smallest_unique_dist(distances, 1)
connections.append([row, col])
k = 2
all_in_one_loop = False
while not all_in_one_loop:
    row, col = find_k_smallest_unique_dist(distances, k)
    print(row, col)
    elements_to_add = {row, col}
    merged = False

    for i, inner_list in enumerate(connections):
        current_set = set(inner_list)
        has_overlap = not elements_to_add.isdisjoint(current_set)
        contains_all_new = elements_to_add.issubset(current_set)

        if contains_all_new:
            merged = True
            break

        if has_overlap and not contains_all_new:
            connections[i] = list(current_set.union(elements_to_add))
            merged = True
            break
    if not merged:
        connections.append(list(elements_to_add))    

    connections = consolidate_connections(connections)

    k += 1

    if k>=10 and len(connections) == 1:
        break
# Out:
# 373 792
# 826 980
# 281 387
# 609 881
# 354 692
# 203 641
# 454 499
# 11 664
# 170 863
# 205 358
# 658 917
# 86 710
# 375 592
# 794 952
# 145 916
# 149 522
# 678 833
# 169 308
# 480 539
# 714 794
# 238 785
# 604 859
# 65 153
# 289 757
# 263 820
# 32 724
# 203 946
# 179 341
# 80 403
# 227 841
# 30 159
# 68 326
# 1 733
# 726 938
# 3 964
# 449 770
# 135 757
# 535 701
# 20 957
# 629 716
# 63 580
# 598 728
# 22 353
# 66 819
# 215 844
# 690 948
# 373 720
# 573 699
# 71 335
# 402 790
# 720 792
# 677 760
# 219 453
# 240 430
# 173 491
# 517 643
# 510 681
# 126 675
# 848 903
# 714 952
# 632 928
# 447 807
# 281 314
# 469 736
# 250 884
# 524 825
# 574 597
# 548 754
# 10 771
# 641 946
# 17 216
# 72 715
# 552 669
# 152 578
# 60 392
# 558 850
# 33 964
# 7 389
# 38 782
# 669 784
# 12 44
# 5 696
# 572 661
# 536 597
# 433 725
# 21 391
# 207 732
# 803 875
# 474 927
# 263 975
# 527 583
# 488 545
# 252 838
# 67 557
# 0 369
# 13 749
# 70 965
# 235 593
# 8 829
# 313 480
# 583 624
# 498 687
# 296 448
# 439 808
# 97 351
# 485 812
# 379 953
# 267 975
# 47 349
# 248 761
# 135 289
# 370 735
# 151 691
# 192 614
# 24 507
# 213 337
# 82 712
# 105 399
# 180 434
# 464 821
# 236 882
# 297 795
# 2 971
# 121 554
# 820 975
# 204 776
# 40 464
# 228 564
# 536 574
# 288 482
# 3 33
# 112 570
# 128 709
# 190 324
# 625 878
# 297 652
# 195 651
# 504 792
# 216 455
# 428 487
# 139 851
# 83 410
# 77 624
# 104 512
# 302 406
# 147 374
# 161 458
# 56 584
# 184 619
# 421 794
# 313 539
# 52 151
# 595 672
# 262 725
# 249 853
# 514 873
# 40 821
# 263 858
# 529 786
# 349 916
# 293 971
# 408 894
# 347 408
# 431 659
# 445 690
# 135 413
# 26 852
# 384 515
# 459 787
# 277 764
# 27 508
# 500 872
# 561 947
# 34 247
# 113 148
# 314 387
# 567 893
# 146 371
# 356 996
# 816 857
# 390 396
# 457 496
# 7 314
# 858 902
# 879 886
# 7 259
# 210 578
# 425 675
# 290 622
# 176 835
# 53 745
# 674 951
# 409 489
# 167 616
# 59 110
# 428 581
# 277 290
# 46 152
# 720 896
# 331 989
# 71 589
# 451 478
# 132 416
# 655 926
# 101 534
# 376 526
# 119 320
# 477 811
# 411 622
# 92 726
# 498 767
# 222 397
# 54 977
# 421 952
# 349 814
# 155 330
# 513 969
# 712 815
# 740 920
# 438 789
# 129 868
# 622 764
# 189 577
# 317 738
# 293 484
# 645 670
# 62 959
# 373 504
# 31 510
# 504 720
# 133 796
# 279 299
# 282 973
# 239 297
# 157 949
# 167 238
# 277 411
# 691 782
# 24 955
# 240 419
# 212 291
# 362 546
# 166 764
# 821 996
# 916 990
# 65 128
# 571 865
# 60 556
# 267 471
# 150 333
# 107 978
# 355 818
# 184 304
# 79 670
# 42 969
# 161 185
# 746 755
# 88 231
# 182 405
# 270 664
# 726 834
# 476 836
# 205 371
# 199 458
# 275 815
# 272 882
# 126 168
# 347 551
# 823 861
# 679 923
# 218 380
# 727 936
# 459 641
# 842 973
# 479 591
# 15 576
# 51 122
# 112 903
# 381 786
# 255 978
# 484 971
# 136 694
# 91 134
# 668 865
# 84 106
# 717 799
# 163 187
# 195 626
# 708 928
# 788 829
# 159 777
# 8 788
# 119 334
# 364 748
# 460 769
# 468 898
# 462 481
# 223 869
# 165 532
# 561 748
# 689 835
# 121 503
# 17 455
# 179 981
# 162 440
# 330 695
# 180 795
# 888 896
# 50 404
# 286 958
# 117 927
# 200 555
# 395 904
# 559 832
# 9 909
# 767 874
# 386 704
# 894 982
# 127 254
# 263 342
# 453 754
# 255 751
# 200 981
# 584 962
# 374 416
# 704 810
# 296 853
# 518 562
# 145 990
# 570 903
# 590 814
# 763 774
# 285 887
# 197 381
# 249 933
# 25 572
# 447 680
# 557 899
# 681 945
# 110 311
# 745 755
# 115 139
# 98 584
# 242 945
# 552 784
# 597 840
# 338 659
# 295 827
# 259 314
# 111 445
# 732 962
# 47 409
# 35 735
# 619 716
# 613 871
# 53 652
# 34 511
# 464 996
# 207 962
# 106 484
# 644 885
# 181 501
# 182 944
# 40 996
# 443 835
# 271 496
# 358 371
# 357 544
# 374 568
# 416 978
# 325 540
# 858 975
# 128 153
# 652 795
# 147 568
# 413 895
# 14 467
# 528 972
# 445 769
# 118 457
# 507 955
# 406 495
# 286 798
# 449 666
# 350 811
# 243 456
# 98 791
# 95 662
# 447 535
# 167 785
# 336 771
# 303 878
# 414 455
# 260 878
# 392 448
# 813 843
# 10 854
# 35 370
# 200 352
# 136 693
# 370 463
# 282 862
# 236 272
# 259 389
# 909 982
# 65 137
# 399 640
# 223 414
# 41 206
# 132 978
# 603 879
# 529 700
# 309 808
# 663 995
# 853 933
# 506 930
# 262 433
# 401 488
# 587 801
# 708 758
# 180 297
# 452 522
# 72 304
# 217 717
# 92 938
# 341 981
# 81 511
# 220 514
# 25 517
# 267 820
# 71 900
# 578 671
# 504 896
# 290 890
# 697 708
# 166 797
# 477 637
# 125 368
# 68 229
# 479 516
# 829 906
# 421 714
# 445 460
# 487 576
# 4 292
# 365 779
# 197 753
# 25 914
# 47 916
# 83 771
# 452 515
# 47 990
# 33 319
# 78 92
# 628 742
# 263 267
# 98 142
# 737 786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[96], line 40
#      38 all_in_one_loop = False
#      39 while not all_in_one_loop:
# ---> 40     row, col = find_k_smallest_unique_dist(distances, k)
#      41     print(row, col)
#      42     elements_to_add = {row, col}
#
# Cell In[96], line 20, in find_k_smallest_unique_dist(distances, k)
#      19 def find_k_smallest_unique_dist(distances, k):
# ---> 20     rows_ut, cols_ut = np.triu_indices_from(distances, k=1)
#      21     unique_distances_subset = distances[rows_ut, cols_ut]
#      22     sorted_indices_of_subset = np.argsort(unique_distances_subset)
#
# File c:\venvs\myenv\Lib\site-packages\numpy\lib\_twodim_base_impl.py:1201, in triu_indices_from(arr, k)
#    1199 if arr.ndim != 2:
#    1200     raise ValueError("input array must be 2-d")
# -> 1201 return triu_indices(arr.shape[-2], k=k, m=arr.shape[-1])
#
# File c:\venvs\myenv\Lib\site-packages\numpy\lib\_twodim_base_impl.py:1137, in triu_indices(n, k, m)
#    1056 """
#    1057 Return the indices for the upper-triangle of an (n, m) array.
#    1058
#    (...)   1133
#    1134 """
#    1135 tri_ = ~tri(n, m, k=k - 1, dtype=bool)
# -> 1137 return tuple(broadcast_to(inds, tri_.shape)[tri_]
#    1138              for inds in indices(tri_.shape, sparse=True))
#
# KeyboardInterrupt:
